# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/DM & ML LAB/Dataset/iris.csv")

# %%
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.4           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.3          0.2     setosa
# 4             5.1          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
print(df.head(10))
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.4           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.3          0.2  setosa
# 4           5.1          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
print(df.tail(10))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# loc
# 1.label based
# 2.loc boolean
# 3.multiple colum
#
# iloc
# 1.index based
# 2.numerical
# 3.single based

# %%
df.loc[0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.4           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.3          0.2  setosa
# 4           5.1          3.6           1.4          0.2  setosa

# %%
df.loc[0:4,['sepal_width']]
# Out:
#    sepal_width
# 0          3.5
# 1          3.4
# 2          3.2
# 3          3.1
# 4          3.6

# %%
df.loc[0:4,['sepal_width','petal_width']]
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.4          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
df.iloc[0:4,0:3]
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.4           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.3

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
max(df['sepal_length'])
# Out:
# 7.9

# %%
min(df['sepal_length'])
# Out:
# 4.3

# %%
np.average(df['sepal_length'])
# Out:
# 5.843999999999999

# %% [markdown]
# find out the unique values for sepal width only for before 7th index

# %%
pd.unique(df['sepal_width'][0:7])
# Out:
# array([3.5, 3.4, 3.2, 3.1, 3.6, 3.9])

# %%
pd.unique(df.loc[0:6, 'sepal_width'])
# Out:
# array([3.5, 3.4, 3.2, 3.1, 3.6, 3.9])

# %%
pd.unique(df.iloc[0:7, 1])
# Out:
# array([3.5, 3.4, 3.2, 3.1, 3.6, 3.9])

# %%
pd.unique(df.loc[0:6, ['sepal_width', 'petal_width', 'sepal_length','petal_length']].values.ravel())
# Out:
# array([3.5, 0.2, 5.1, 1.4, 3.4, 4.9, 3.2, 4.7, 1.3, 3.1, 4.6, 3.6, 3.9,
#        0.4, 5.4, 1.7, 0.3])
