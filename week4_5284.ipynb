# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/DM & ML LAB/Dataset/iris.csv")

# %%
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.4           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.3          0.2     setosa
# 4             5.1          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import statistics as st

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
x=df['sepal_length']
y=df['sepal_width']
a=df['petal_length']
b=df['petal_width']
plt.scatter(x,y,color='blue',label='Line')
plt.scatter(a,b,color='red',label='Line')
plt.legend()
plt.grid()
plt.show()

# %%
x=df['sepal_length']
y=df['sepal_width']
a=df['petal_length']
b=df['petal_width']
plt.title('Sepal vs Petal')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.scatter(x,y,color='blue',label='sepal length & width')
plt.scatter(a,b,color='red',label='Petal length & width')
plt.legend()
plt.grid()
plt.show()

# %%
x=[10,25,11,21,14,10,30,4]
y=[10,20,30,40,50, 1, 2, 3]
a=[4,54,85,10,21,41,61,16]
b=[85,41,65,21,25, 1, 4, 6]
plt.title('Information')
plt.xlabel('Days')
plt.ylabel('Distence km')
plt.bar(x,y,label='bmw',color='blue',width=5)
plt.bar(a,b,label='audi',color='green',width=5)
plt.legend()
plt.show()

# %%
data=df['species'].value_counts()
name=data.index
count=data.values
plt.title('Score')
plt.xlabel('Name')
plt.ylabel('Toatl count')
plt.bar(name,count)
plt.show()

# %%
data=df['species'].value_counts()
name=data.index
count=data.values
plt.title('Score')
plt.xlabel('Name')
plt.ylabel('Toatl count')
plt.barh(name,count)
plt.show()

# %%
slice=[4,2,1,3]
acitvity=['running','walking','cycling','swimming']
color=['g','b','b','m']
plt.pie(slice,labels=acitvity,colors=color,startangle=90,shadow=True,explode=(0,0.1,0,0),autopct='%1.1f%%')
plt.show()

# %%
x=[10,25,11,21,14,10,30,4,10,20,30,40,50, 1, 2, 3]
plt.hist(x,bins=10,edgecolor='red',linewidth=1)
plt.show()

# %%
x=[3.6,4.2,6.9,5.3,6.2,2.1,3.1,8.6,9.2]
y=[70,88,33,50,46,15,5,9,23]
plt.title('Exercies 1')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.bar(x,y,label='ab',color='blue',width=0.5)
plt.legend()
plt.show()

# %%
x=[3.6,4.2,6.9,5.3,6.2,2.1,3.1,8.6,9.2]
y=[70,88,33,50,46,15,5,9,23]
plt.title('Exercies 1')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.scatter(x,y,color='blue',label='dot')
plt.grid()
plt.legend()

# %%
sb.scatterplot(x='sepal_width', y='sepal_length', data=df)
plt.show()

sb.scatterplot(x='petal_width', y='petal_length', data=df)
plt.show()

sb.boxplot(x='sepal_width', data=df)
plt.show()

sb.boxplot(x='sepal_length', data=df)
plt.show()

sb.boxplot(x='petal_width', data=df)
plt.show()

sb.boxplot(x='petal_length', data=df)
plt.show()
