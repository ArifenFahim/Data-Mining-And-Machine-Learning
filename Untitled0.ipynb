# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv("/content/drive/MyDrive/DM & ML LAB/Dataset/healthcare-dataset-stroke-data.csv")

# %%
print(df)

# %%
import statistics as st

# %%
new_df = df[['age', 'avg_glucose_level', 'bmi']]

# %%
num_rows = int(0.25 * len(new_df))

# %%
std_dev = new_df.head(num_rows).std()
print(std_dev)

# %%
import matplotlib.pyplot as plt
import seaborn as sb
